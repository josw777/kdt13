# %% [markdown]
# # 판다스
# 가나다라 가나다라 가나다라 가나다라 가나다라 가나다라
# 가나다라
#
# ## 취미
# - 등산
#     - 내연산
#         - 1111
#     - 팔공산
#     - 북한산
# - 영화
#     - 왕과 사는 남자
#     - 왕의 남자
#
# ## 취미
# 1. 등산
#     1) 내연산
#     2) 주왕산
# 2. 영화
#     1) 왕과 사는 남자
#     2) 왕의 남자
#
# ![image.png](attachment:b2f88678-ee8e-4fb8-bb72-6a5827691e15.png)

# %%
# cell 단위로 실행 가능
print("안녕하세요")
# Out:
# 안녕하세요
